# %%
# !pip install -q requests

# %%
import requests

API_KEY = "sk-or-v1-"

# %%
import requests

url = "https://openrouter.ai/api/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json"
}

data = {
    "model": "minimax/minimax-m3:free",
    "messages": [
        {
            "role": "user",
            "content": "Explain Generative AI in 3 simple sentences."
        }
    ]
}

response = requests.post(
    url,
    headers=headers,
    json=data
)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# - Generative AI is a type of artificial intelligence that creates new content—such as text, images, audio, or code—by learning patterns from existing data.
# - It uses large models, like neural networks, to generate outputs that mimic human creativity and decision-making.
# - Popular examples include chatbots (like ChatGPT), image generators (like DALL·E), and code assistants (like GitHub Copilot).
